# %% [markdown]
# <a href="https://colab.research.google.com/github/zahra-ziaei/Personal-Finance-Management-datamining/blob/master/BSAN_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import pandas as pd
import numpy as np
from google.colab import files

# %%
#upload a file from ur pc to GoogleColab
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3811dd9f-9105-4c61-8be7-0a1f0f3638ed" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3811dd9f-9105-4c61-8be7-0a1f0f3638ed">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#read the uploaded file
stocks=pd.read_csv('stocks3.csv')

# %% [markdown]
# Exploratory Data Analysis

# %%
stocks.head(10)
# Out:
#         Date        AAPL        MSFT      GOOGL       AMZN        TSLA
# 0   1/3/2023         NaN  239.580002  89.120003  85.820000  108.099998
# 1   1/4/2023  126.360001         NaN        NaN  85.139999  113.639999
# 2   1/5/2023  125.019997  222.309998  86.199997  83.120003  110.339996
# 3   1/6/2023  129.619995  224.929993  87.339996  86.080002  113.059998
# 4   1/9/2023  130.149994  227.119995  88.019997  87.360001  119.769997
# 5  1/10/2023  130.729996  228.850006  88.419998  89.870003  118.849998
# 6  1/11/2023  133.490005  235.770004  91.519997  95.089996  123.220001
# 7  1/12/2023  133.410004  238.509995  91.129997  95.269997  123.559998
# 8  1/13/2023  134.759995  239.229996  92.120003  98.120003  122.400002
# 9  1/17/2023  135.940002  240.350006  91.290001  96.050003  131.490005

# %%
stocks.tail()
# Out:
#           Date        AAPL        MSFT       GOOGL        AMZN        TSLA
# 164  8/29/2023  184.119995  328.410004  134.570007  134.910004  257.179993
# 165  8/30/2023  187.649994  328.790008  135.880005  135.070007  256.899994
# 166  8/31/2023  187.869995  327.760010  136.169998  138.009995  258.079987
# 167  8/30/2023  187.649994  328.790008  135.880005  135.070007  256.899994
# 168  8/31/2023  187.869995  327.760010  136.169998  138.009995  258.079987

# %%
display(stocks)
# Out:
#           Date        AAPL        MSFT       GOOGL        AMZN        TSLA
# 0     1/3/2023         NaN  239.580002   89.120003   85.820000  108.099998
# 1     1/4/2023  126.360001         NaN         NaN   85.139999  113.639999
# 2     1/5/2023  125.019997  222.309998   86.199997   83.120003  110.339996
# 3     1/6/2023  129.619995  224.929993   87.339996   86.080002  113.059998
# 4     1/9/2023  130.149994  227.119995   88.019997   87.360001  119.769997
# ..         ...         ...         ...         ...         ...         ...
# 164  8/29/2023  184.119995  328.410004  134.570007  134.910004  257.179993
# 165  8/30/2023  187.649994  328.790008  135.880005  135.070007  256.899994
# 166  8/31/2023  187.869995  327.760010  136.169998  138.009995  258.079987
# 167  8/30/2023  187.649994  328.790008  135.880005  135.070007  256.899994
# 168  8/31/2023  187.869995  327.760010  136.169998  138.009995  258.079987
#
# [169 rows x 6 columns]

# %%
stocks.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_7c33e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c33e_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_7c33e_level0_col1" class="col_heading level0 col1" >AAPL</th>
#       <th id="T_7c33e_level0_col2" class="col_heading level0 col2" >MSFT</th>
#       <th id="T_7c33e_level0_col3" class="col_heading level0 col3" >GOOGL</th>
#       <th id="T_7c33e_level0_col4" class="col_heading level0 col4" >AMZN</th>
#       <th id="T_7c33e_level0_col5" class="col_heading level0 col5" >TSLA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c33e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7c33e_row0_col0" class="data row0 col0" >1/3/2023</td>
#       <td id="T_7c33e_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_7c33e_row0_col2" class="data row0 col2" >239.580002</td>
# ...

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    169 non-null    object
#  1   AAPL    168 non-null    float64
#  2   MSFT    168 non-null    float64
#  3   GOOGL   168 non-null    float64
#  4   AMZN    169 non-null    float64
#  5   TSLA    169 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 8.0+ KB

# %%
#drop duplicates
stocks.drop_duplicates(inplace=True)

# %%
stocks.tail()
# Out:
#           Date        AAPL        MSFT       GOOGL        AMZN        TSLA
# 162  8/25/2023  178.610001  322.980011  129.880005  133.259995  238.589996
# 163  8/28/2023  180.190002  323.700012  131.009995  133.139999  238.820007
# 164  8/29/2023  184.119995  328.410004  134.570007  134.910004  257.179993
# 165  8/30/2023  187.649994  328.790008  135.880005  135.070007  256.899994
# 166  8/31/2023  187.869995  327.760010  136.169998  138.009995  258.079987

# %%
#drop nulls
stocks.dropna(inplace=True)

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 165 entries, 2 to 166
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    165 non-null    object
#  1   AAPL    165 non-null    float64
#  2   MSFT    165 non-null    float64
#  3   GOOGL   165 non-null    float64
#  4   AMZN    165 non-null    float64
#  5   TSLA    165 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 9.0+ KB

# %%
stocks.describe()
# Out:
#              AAPL        MSFT       GOOGL        AMZN        TSLA
# count  165.000000  165.000000  165.000000  165.000000  165.000000
# mean   167.960121  297.422000  111.339394  112.922546  206.274727
# std     17.757613   36.352625   14.068683   15.945088   43.821618
# min    125.019997  222.309998   86.199997   83.120003  110.339996
# 25%    153.199997  264.600006   99.370003   98.709999  177.899994
# 50%    169.679993  307.000000  107.739998  106.620003  196.880005
# 75%    181.119995  328.790008  123.639999  128.800003  249.699997
# max    196.449997  359.489990  136.169998  142.220001  293.339996

# %%
stocks['AAPL'].mode()
# Out:
# 0    163.759995
# 1    172.070007
# Name: AAPL, dtype: float64

# %%
stocks['MSFT'].mode()
# Out:
# 0    305.410004
# Name: MSFT, dtype: float64

# %%
count=stocks['AAPL'].count()
mean=stocks['AAPL'].mean()
median=stocks['AAPL'].median()
min=stocks['AAPL'].min()
max=stocks['AAPL'].max()
std=stocks['AAPL'].std()
var=stocks['AAPL'].var()
print(count)
print(mean)
print(median)
print(min)
print(max)
print(std)
print(var)
# Out:
# 165
# 167.9601212448485
# 169.6799927
# 125.0199966
# 196.4499969
# 17.757612889122395
# 315.3328155199258

# %%
stocks['AAPL'].quantile([0.25, 0.5, 0.75])
# Out:
# 0.25    153.199997
# 0.50    169.679993
# 0.75    181.119995
# Name: AAPL, dtype: float64

# %%
stock_withoutdate=stocks.drop('Date',axis=1)
stock_withoutdate.corr()
# Out:
#            AAPL      MSFT     GOOGL      AMZN      TSLA
# AAPL   1.000000  0.977784  0.890748  0.886687  0.843323
# MSFT   0.977784  1.000000  0.914367  0.900243  0.791175
# GOOGL  0.890748  0.914367  1.000000  0.951458  0.724612
# AMZN   0.886687  0.900243  0.951458  1.000000  0.821079
# TSLA   0.843323  0.791175  0.724612  0.821079  1.000000

# %%
stock_withoutdate.cov()
# Out:
#              AAPL         MSFT       GOOGL        AMZN         TSLA
# AAPL   315.332816   631.194371  222.532227  251.062642   656.246337
# MSFT   631.194371  1321.513357  467.638165  521.821931  1260.366063
# GOOGL  222.532227   467.638165  197.927830  213.437089   446.732589
# AMZN   251.062642   521.821931  213.437089  254.245846   573.720143
# TSLA   656.246337  1260.366063  446.732589  573.720143  1920.334189

# %% [markdown]
# Data Visualization

# %%
stock_withoutdate.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
stocks.AAPL.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
#histogram
stocks.AAPL.plot.hist(by=None, bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
stocks.AAPL.plot.hist(by=None, bins=5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
stocks.AAPL.plot.hist(by=None, bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
#boxplot
stocks.AAPL.plot.box()
# Out:
# <Axes: >

# %%
stocks.boxplot(column=['AAPL','MSFT',	'GOOGL',	'AMZN',	'TSLA'])
# Out:
# <Axes: >

# %%
#scatter plot
stocks.plot.scatter(x='AAPL', y='MSFT')
# Out:
# <Axes: xlabel='AAPL', ylabel='MSFT'>

# %%
stocks.plot.scatter('AAPL','GOOGL')
# Out:
# <Axes: xlabel='AAPL', ylabel='GOOGL'>

# %%
#matrix_scatter
from pandas.plotting import scatter_matrix
scatter_matrix(stocks)
# Out:
# array([[<Axes: xlabel='AAPL', ylabel='AAPL'>,
#         <Axes: xlabel='MSFT', ylabel='AAPL'>,
#         <Axes: xlabel='GOOGL', ylabel='AAPL'>,
#         <Axes: xlabel='AMZN', ylabel='AAPL'>,
#         <Axes: xlabel='TSLA', ylabel='AAPL'>],
#        [<Axes: xlabel='AAPL', ylabel='MSFT'>,
#         <Axes: xlabel='MSFT', ylabel='MSFT'>,
#         <Axes: xlabel='GOOGL', ylabel='MSFT'>,
#         <Axes: xlabel='AMZN', ylabel='MSFT'>,
#         <Axes: xlabel='TSLA', ylabel='MSFT'>],
#        [<Axes: xlabel='AAPL', ylabel='GOOGL'>,
#         <Axes: xlabel='MSFT', ylabel='GOOGL'>,
#         <Axes: xlabel='GOOGL', ylabel='GOOGL'>,
#         <Axes: xlabel='AMZN', ylabel='GOOGL'>,
#         <Axes: xlabel='TSLA', ylabel='GOOGL'>],
#        [<Axes: xlabel='AAPL', ylabel='AMZN'>,
#         <Axes: xlabel='MSFT', ylabel='AMZN'>,
#         <Axes: xlabel='GOOGL', ylabel='AMZN'>,
#         <Axes: xlabel='AMZN', ylabel='AMZN'>,
#         <Axes: xlabel='TSLA', ylabel='AMZN'>],
# ...

# %%
data = {
    'Color': ['Red', 'Blue', 'Green', 'Blue', 'Red','Red', 'Blue', 'Green', 'Blue', 'Red','Red', 'Blue', 'Green', 'Blue', 'Red'],
    'Size': ['Small', 'Medium', 'Large', 'Medium', 'Small','Medium', 'Large', 'Medium', 'Small','Medium', 'Large', 'Medium', 'Small', 'Large','Large']
}
df = pd.DataFrame(data)
df
# Out:
#     Color    Size
# 0     Red   Small
# 1    Blue  Medium
# 2   Green   Large
# 3    Blue  Medium
# 4     Red   Small
# 5     Red  Medium
# 6    Blue   Large
# 7   Green  Medium
# 8    Blue   Small
# 9     Red  Medium
# 10    Red   Large
# 11   Blue  Medium
# 12  Green   Small
# 13   Blue   Large
# 14    Red   Large

# %%
df['Size'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Size'>

# %%
df['Size'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>
